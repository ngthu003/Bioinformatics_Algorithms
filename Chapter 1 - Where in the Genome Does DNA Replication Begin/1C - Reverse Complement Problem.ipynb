# %% [markdown]
# __[Problem 1C](http://rosalind.info/problems/ba1c/)__
#
# >  __Reverse Complement Problem__ - `ReverseComplement(Pattern)`
#
# *Objective:* Find the reverse complement of a DNA string
#
# *  Input: a DNA string *Pattern*
# *  Output: $\overline{Pattern}$, the reverse complement of *Pattern*

# %%
DNAdict = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

def ReverseComplement( Pattern ):
    RC = str()
    for i in reversed(Pattern):
        if i in DNAdict.keys():
            RC += DNAdict[i]
        else:
            RC = 'Wrong DNA'
            break
    return RC

# %%
print('Sample test: Reverse Complement is ' + str(ReverseComplement('AAAACCCGGT')))
# Out:
# Sample test: Reverse Complement is ACCGGGTTTT

# %%
print('Test 1: Reverse Complement is ' + str(ReverseComplement('ACACAC')))
# Out:
# Test 1: Reverse Complement is GTGTGT

# %% [markdown]
# <br/>
#
# [Rosalind final test:](http://rosalind.info/problems/ba1c/)

# %%
test = '...'
ReverseComplement(test)
# Out:
# '...'
